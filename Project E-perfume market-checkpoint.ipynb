# %% [markdown]
#  # import libraries

# %%
import numpy as np  
import pandas as pd 
import os
from sqlite3 import connect

# %%
  import matplotlib.pyplot as plt
from matplotlib.pyplot import figure as fig
import seaborn as sns
from scipy.stats import linregress
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

# %% [markdown]
# # Read the .csv file.

# %%
data = pd.read_csv("noon_perfumes_dataset.csv")

# %%
data
# Out:
#       Unnamed: 0            brand                      name  old_price  \
# 0              0     PACO RABANNE           1 Million Lucky      395.0
# 1              1  Roberto Cavalli         Paradiso Assoluto      415.0
# 2              2       S.T.Dupont               Royal Amber      265.0
# 3              3            GUESS            Seductive Blue      290.0
# 4              4  Roberto Cavalli                      Uomo      260.0
# ...          ...              ...                       ...        ...
# 998          998            GUESS                      Dare      170.0
# 999          999         BURBERRY  For Women EDP Natural Sp      378.0
# 1000        1000            JOVAN           Musk Cologne Sp       55.0
# 1001        1001    SWISS ARABIAN             Layali CPO At      126.0
# 1002        1002          LACOSTE        L.12.12 Blanc-Pure      347.0
#
#       new_price   ml concentration department   scents  \
# 0        244.55  100           EDT        Men    Woody
# 1        107.95   50           EDP      Women   Floral
# 2        186.90  100           EDP     Unisex  Arabian
# 3        103.20  100           EDT        Men    Spicy
# 4         94.95   50           EDP      Women  Arabian
# ...         ...  ...           ...        ...      ...
# 998       75.00  100           EDT      Women   Citrus
# 999      153.75  100           EDT      Women   Fruity
# 1000      19.00   59           EDT      Women    Woody
# 1001      77.00   15           EDT     Unisex  Arabian
# 1002      94.20  100           EDT        Men    Woody
#
#                                         base_note  \
# 0                  Oakmoss, Patchouli and Vetiver
# 1               Vanilla, Sandalwood And Patchouli
# 2                       Lemon, Mint and Wood Moss
# 3     Cashmere Wood, Moss And Rippled Sand Accord
# 4                    Vanille, Benzoin, Tonka Bean
# ...                                           ...
# 998                   Coconut Accords, Wood, Musk
# 999                              Musk And Vanilla
# 1000                            Musk, Amber, Wood
# 1001                           Agarwood and Amber
# 1002      Virginia Cedar, Leather, Suede, Vetiver
#
#                                            middle_note  item_rating  \
# 0     Hazelnut, Jasmine, Cashmir Wood, Cedar and Honey          5.0
# 1                            Wild Jasmine and Red Lily          4.8
# 2                                 Sandalwood and Cedar          5.0
# 3             Blue Coral Aquaspace Accord And Geranium          3.0
# 4                                African Orange Flower          4.8
# ...                                                ...          ...
# 998                         Wild Rose, Elegant Jasmine          4.9
# 999                 Woody-Floral, Sandalwood And Cedar          4.8
# 1000                                       Ylang-ylang          4.7
# 1001                     Ylang-Ylang, Rose and Jasmine          4.0
# 1002                             Ylang-Ylang, Tuberose          4.6
#
#                                                  seller  seller_rating  \
# 0                                                  noon            4.2
# 1                                                  noon            4.2
# 2                                                  noon            4.2
# 3                                                  noon            4.2
# 4                                                  noon            4.2
# ...                                                 ...            ...
# 998                                                noon            4.2
# 999                                                noon            4.2
# 1000                                               Cute            3.7
# 1001  Swiss Arabian PerfumesPRICE UPDATE WITH 15% VA...            3.9
# 1002                                               noon            4.2
#
#      num_seller_ratings
# 0                 98.1K
# 1                 98.1K
# 2                 98.1K
# 3                 98.1K
# 4                 98.1K
# ...                 ...
# 998               98.1K
# 999               98.1K
# 1000               1.9K
# 1001                  5
# 1002              98.1K
#
# [1003 rows x 15 columns]

# %% [markdown]
# # Show information about data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1003 entries, 0 to 1002
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1003 non-null   int64
#  1   brand               1003 non-null   object
#  2   name                1003 non-null   object
#  3   old_price           1003 non-null   float64
#  4   new_price           1003 non-null   float64
#  5   ml                  1003 non-null   int64
#  6   concentration       1003 non-null   object
#  7   department          1003 non-null   object
#  8   scents              1003 non-null   object
#  9   base_note           1003 non-null   object
#  10  middle_note         1003 non-null   object
#  11  item_rating         1003 non-null   float64
#  12  seller              1003 non-null   object
#  13  seller_rating       1003 non-null   float64
#  14  num_seller_ratings  1003 non-null   object
# dtypes: float64(4), int64(2), object(9)
# memory usage: 117.7+ KB

# %% [markdown]
# # Exploring Data

# %%
data.num_seller_ratings.describe()
# Out:
# count      1003
# unique       60
# top       98.1K
# freq        287
# Name: num_seller_ratings, dtype: object

# %%
data.new_price.describe()
# Out:
# count    1003.000000
# mean      149.574307
# std       108.686013
# min         5.350000
# 25%        80.325000
# 50%       135.000000
# 75%       198.525000
# max       904.850000
# Name: new_price, dtype: float64

# %%
data.num_seller_ratings.describe()
# Out:
# count      1003
# unique       60
# top       98.1K
# freq        287
# Name: num_seller_ratings, dtype: object

# %%
data.old_price.mean()
# Out:
# 321.17602193419737

# %%
data.new_price.value_counts()
# Out:
# 140.00    8
# 95.00     7
# 115.00    7
# 126.00    6
# 110.00    6
#          ..
# 119.95    1
# 886.00    1
# 83.70     1
# 94.15     1
# 10.60     1
# Name: new_price, Length: 644, dtype: int64

# %% [markdown]
#  checking types of all columns

# %%
data.dtypes
# Out:
# Unnamed: 0              int64
# brand                  object
# name                   object
# old_price             float64
# new_price             float64
# ml                      int64
# concentration          object
# department             object
# scents                 object
# base_note              object
# middle_note            object
# item_rating           float64
# seller                 object
# seller_rating         float64
# num_seller_ratings     object
# dtype: object

# %% [markdown]
# Visually inspect

# %%
data.head()
# Out:
#    Unnamed: 0            brand               name  old_price  new_price   ml  \
# 0           0     PACO RABANNE    1 Million Lucky      395.0     244.55  100
# 1           1  Roberto Cavalli  Paradiso Assoluto      415.0     107.95   50
# 2           2       S.T.Dupont        Royal Amber      265.0     186.90  100
# 3           3            GUESS     Seductive Blue      290.0     103.20  100
# 4           4  Roberto Cavalli               Uomo      260.0      94.95   50
#
#   concentration department   scents  \
# 0           EDT        Men    Woody
# 1           EDP      Women   Floral
# 2           EDP     Unisex  Arabian
# 3           EDT        Men    Spicy
# 4           EDP      Women  Arabian
#
#                                      base_note  \
# 0               Oakmoss, Patchouli and Vetiver
# 1            Vanilla, Sandalwood And Patchouli
# 2                    Lemon, Mint and Wood Moss
# 3  Cashmere Wood, Moss And Rippled Sand Accord
# 4                 Vanille, Benzoin, Tonka Bean
#
#                                         middle_note  item_rating seller  \
# 0  Hazelnut, Jasmine, Cashmir Wood, Cedar and Honey          5.0   noon
# 1                         Wild Jasmine and Red Lily          4.8   noon
# 2                              Sandalwood and Cedar          5.0   noon
# 3          Blue Coral Aquaspace Accord And Geranium          3.0   noon
# 4                             African Orange Flower          4.8   noon
#
#    seller_rating num_seller_ratings
# 0            4.2              98.1K
# 1            4.2              98.1K
# 2            4.2              98.1K
# 3            4.2              98.1K
# 4            4.2              98.1K

# %%
data.tail()
# Out:
#       Unnamed: 0          brand                      name  old_price  \
# 998          998          GUESS                      Dare      170.0
# 999          999       BURBERRY  For Women EDP Natural Sp      378.0
# 1000        1000          JOVAN           Musk Cologne Sp       55.0
# 1001        1001  SWISS ARABIAN             Layali CPO At      126.0
# 1002        1002        LACOSTE        L.12.12 Blanc-Pure      347.0
#
#       new_price   ml concentration department   scents  \
# 998       75.00  100           EDT      Women   Citrus
# 999      153.75  100           EDT      Women   Fruity
# 1000      19.00   59           EDT      Women    Woody
# 1001      77.00   15           EDT     Unisex  Arabian
# 1002      94.20  100           EDT        Men    Woody
#
#                                     base_note  \
# 998               Coconut Accords, Wood, Musk
# 999                          Musk And Vanilla
# 1000                        Musk, Amber, Wood
# 1001                       Agarwood and Amber
# 1002  Virginia Cedar, Leather, Suede, Vetiver
#
#                              middle_note  item_rating  \
# 998           Wild Rose, Elegant Jasmine          4.9
# 999   Woody-Floral, Sandalwood And Cedar          4.8
# 1000                         Ylang-ylang          4.7
# 1001       Ylang-Ylang, Rose and Jasmine          4.0
# 1002               Ylang-Ylang, Tuberose          4.6
#
#                                                  seller  seller_rating  \
# 998                                                noon            4.2
# 999                                                noon            4.2
# 1000                                               Cute            3.7
# 1001  Swiss Arabian PerfumesPRICE UPDATE WITH 15% VA...            3.9
# 1002                                               noon            4.2
#
#      num_seller_ratings
# 998               98.1K
# 999               98.1K
# 1000               1.9K
# 1001                  5
# 1002              98.1K

# %% [markdown]
# # Divide columns into two categories

# %%
cols_data = pd.DataFrame(data.dtypes)
num_cols = list(cols_data[cols_data[0]=='int64'].index)
cat_cols = list(cols_data[cols_data[0]=='object'].index)
print('Numeric variables includes:','\n',num_cols)
print('\nCategorical variables includes','\n',cat_cols)
# Out:
# Numeric variables includes:
#  ['Unnamed: 0', 'ml']
#
# Categorical variables includes
#  ['brand', 'name', 'concentration', 'department', 'scents', 'base_note', 'middle_note', 'seller', 'num_seller_ratings']

# %% [markdown]
# # Data cleaning

# %%
data.isna()
# Out:
#       Unnamed: 0  brand   name  old_price  new_price     ml  concentration  \
# 0          False  False  False      False      False  False          False
# 1          False  False  False      False      False  False          False
# 2          False  False  False      False      False  False          False
# 3          False  False  False      False      False  False          False
# 4          False  False  False      False      False  False          False
# ...          ...    ...    ...        ...        ...    ...            ...
# 998        False  False  False      False      False  False          False
# 999        False  False  False      False      False  False          False
# 1000       False  False  False      False      False  False          False
# 1001       False  False  False      False      False  False          False
# 1002       False  False  False      False      False  False          False
#
#       department  scents  base_note  middle_note  item_rating  seller  \
# 0          False   False      False        False        False   False
# 1          False   False      False        False        False   False
# 2          False   False      False        False        False   False
# 3          False   False      False        False        False   False
# 4          False   False      False        False        False   False
# ...          ...     ...        ...          ...          ...     ...
# 998        False   False      False        False        False   False
# 999        False   False      False        False        False   False
# 1000       False   False      False        False        False   False
# 1001       False   False      False        False        False   False
# 1002       False   False      False        False        False   False
#
#       seller_rating  num_seller_ratings
# 0             False               False
# 1             False               False
# 2             False               False
# 3             False               False
# 4             False               False
# ...             ...                 ...
# 998           False               False
# 999           False               False
# 1000          False               False
# 1001          False               False
# 1002          False               False
#
# [1003 rows x 15 columns]

# %% [markdown]
# Use .isna() result as data mask

# %%
data[data.name.isna()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, brand, name, old_price, new_price, ml, concentration, department, scents, base_note, middle_note, item_rating, seller, seller_rating, num_seller_ratings]
# Index: []

# %% [markdown]
# Understand how the data looks like and determine whether there is an null.

# %%
print(data.shape)
print(data.isna().sum())   
data.head()
# Out:
# (1003, 15)
# Unnamed: 0            0
# brand                 0
# name                  0
# old_price             0
# new_price             0
# ml                    0
# concentration         0
# department            0
# scents                0
# base_note             0
# middle_note           0
# item_rating           0
# seller                0
# seller_rating         0
# num_seller_ratings    0
# dtype: int64
#    Unnamed: 0            brand               name  old_price  new_price   ml  \
# 0           0     PACO RABANNE    1 Million Lucky      395.0     244.55  100
# 1           1  Roberto Cavalli  Paradiso Assoluto      415.0     107.95   50
# 2           2       S.T.Dupont        Royal Amber      265.0     186.90  100
# 3           3            GUESS     Seductive Blue      290.0     103.20  100
# 4           4  Roberto Cavalli               Uomo      260.0      94.95   50
#
#   concentration department   scents  \
# 0           EDT        Men    Woody
# 1           EDP      Women   Floral
# 2           EDP     Unisex  Arabian
# 3           EDT        Men    Spicy
# 4           EDP      Women  Arabian
#
#                                      base_note  \
# 0               Oakmoss, Patchouli and Vetiver
# 1            Vanilla, Sandalwood And Patchouli
# 2                    Lemon, Mint and Wood Moss
# 3  Cashmere Wood, Moss And Rippled Sand Accord
# 4                 Vanille, Benzoin, Tonka Bean
#
#                                         middle_note  item_rating seller  \
# 0  Hazelnut, Jasmine, Cashmir Wood, Cedar and Honey          5.0   noon
# 1                         Wild Jasmine and Red Lily          4.8   noon
# 2                              Sandalwood and Cedar          5.0   noon
# 3          Blue Coral Aquaspace Accord And Geranium          3.0   noon
# 4                             African Orange Flower          4.8   noon
#
#    seller_rating num_seller_ratings
# 0            4.2              98.1K
# 1            4.2              98.1K
# 2            4.2              98.1K
# 3            4.2              98.1K
# 4            4.2              98.1K

# %% [markdown]
# # drop a column

# %%
data.drop('Unnamed: 0',
         axis='columns', inplace=True)

# %%
data
# Out:
#                 brand                      name  old_price  new_price   ml  \
# 0        PACO RABANNE           1 Million Lucky      395.0     244.55  100
# 1     Roberto Cavalli         Paradiso Assoluto      415.0     107.95   50
# 2          S.T.Dupont               Royal Amber      265.0     186.90  100
# 3               GUESS            Seductive Blue      290.0     103.20  100
# 4     Roberto Cavalli                      Uomo      260.0      94.95   50
# ...               ...                       ...        ...        ...  ...
# 998             GUESS                      Dare      170.0      75.00  100
# 999          BURBERRY  For Women EDP Natural Sp      378.0     153.75  100
# 1000            JOVAN           Musk Cologne Sp       55.0      19.00   59
# 1001    SWISS ARABIAN             Layali CPO At      126.0      77.00   15
# 1002          LACOSTE        L.12.12 Blanc-Pure      347.0      94.20  100
#
#      concentration department   scents  \
# 0              EDT        Men    Woody
# 1              EDP      Women   Floral
# 2              EDP     Unisex  Arabian
# 3              EDT        Men    Spicy
# 4              EDP      Women  Arabian
# ...            ...        ...      ...
# 998            EDT      Women   Citrus
# 999            EDT      Women   Fruity
# 1000           EDT      Women    Woody
# 1001           EDT     Unisex  Arabian
# 1002           EDT        Men    Woody
#
#                                         base_note  \
# 0                  Oakmoss, Patchouli and Vetiver
# 1               Vanilla, Sandalwood And Patchouli
# 2                       Lemon, Mint and Wood Moss
# 3     Cashmere Wood, Moss And Rippled Sand Accord
# 4                    Vanille, Benzoin, Tonka Bean
# ...                                           ...
# 998                   Coconut Accords, Wood, Musk
# 999                              Musk And Vanilla
# 1000                            Musk, Amber, Wood
# 1001                           Agarwood and Amber
# 1002      Virginia Cedar, Leather, Suede, Vetiver
#
#                                            middle_note  item_rating  \
# 0     Hazelnut, Jasmine, Cashmir Wood, Cedar and Honey          5.0
# 1                            Wild Jasmine and Red Lily          4.8
# 2                                 Sandalwood and Cedar          5.0
# 3             Blue Coral Aquaspace Accord And Geranium          3.0
# 4                                African Orange Flower          4.8
# ...                                                ...          ...
# 998                         Wild Rose, Elegant Jasmine          4.9
# 999                 Woody-Floral, Sandalwood And Cedar          4.8
# 1000                                       Ylang-ylang          4.7
# 1001                     Ylang-Ylang, Rose and Jasmine          4.0
# 1002                             Ylang-Ylang, Tuberose          4.6
#
#                                                  seller  seller_rating  \
# 0                                                  noon            4.2
# 1                                                  noon            4.2
# 2                                                  noon            4.2
# 3                                                  noon            4.2
# 4                                                  noon            4.2
# ...                                                 ...            ...
# 998                                                noon            4.2
# 999                                                noon            4.2
# 1000                                               Cute            3.7
# 1001  Swiss Arabian PerfumesPRICE UPDATE WITH 15% VA...            3.9
# 1002                                               noon            4.2
#
#      num_seller_ratings
# 0                 98.1K
# 1                 98.1K
# 2                 98.1K
# 3                 98.1K
# 4                 98.1K
# ...                 ...
# 998               98.1K
# 999               98.1K
# 1000               1.9K
# 1001                  5
# 1002              98.1K
#
# [1003 rows x 14 columns]

# %%
data.brand.unique()  #Unique values in the Brand Data column
# Out:
# array(['PACO RABANNE', 'Roberto Cavalli', 'S.T.Dupont', 'GUESS',
#        'HUGO BOSS', 'DORALL COLLECTION', 'GUCCI', 'Yves Saint Laurent',
#        'CERRUTI 1881', 'Calvin Klein', 'Rasasi', 'MONTALE', 'CHLOE',
#        'NARCISO RODRIGUEZ', 'BOUCHERON', 'Alina Corel', 'Revlon',
#        'TED LAPIDUS', 'Britney Spears', 'Van Cleef & Arpels',
#        'Estee Lauder', 'Geoffrey Beene', 'Dolce & Gabbana', 'Mancera',
#        'Dior', 'BURBERRY', 'AIGNER', 'BENTLEY', 'VERSACE',
#        'Juicy Couture', 'Laura Mars', 'GIORGIO ARMANI', 'HERMES',
#        'Elizabeth Arden', 'Benetton', 'Giorgio Beverly Hills', 'Guerlain',
#        'Jean Paul GAULTIER', 'Ajmal', 'J.CASANOVA',
#        'UNITED COLORS OF BENETTON', 'YSL', 'TOMMY HILFIGER',
#        'RALPH LAUREN', 'EMPORIO ARMANI', 'armani', 'VALENTINO',
#        'Ard Al Zaafaran', 'DKNY', 'CAROLINA HERRERA', 'ELIE SAAB',
#        'MONTBLANC', 'LACOSTE', 'LE CHAMEAU', 'AVON',
#        'Salvatore Ferragamo', 'Carrera', 'Sedr Al-Khaleej Perfumes',
#        'Dunhill', 'TRUSSARDI', 'Dupont', 'ANGEL SCHLESSER', 'DAVIDOFF',
#        'CHOPARD', 'CARTIER', 'jennifer lopez', 'BVLGARI', 'Ferrari',
#        'Alrehab', 'Genie', 'LALIQUE', 'Franck Olivier', 'cacharel',
#        'Al Fakhr', 'Givenchy', 'JAGUAR', 'Pino Silvestre', 'Kenneth Cole',
#        'Lattafa', 'Kenzo', 'Mariah Carey', 'PRADA', 'Milton Lloyd',
#        'COACH', 'Marbert', 'AMOUAGE', 'joop', 'LOEWE', 'KORLOFF',
#        'LANVIN', 'Jimmy Choo', 'Lancome', 'AZZARO', 'ESCADA',
#        'Jacques Bogart', 'Paris Hilton', 'PRIVE', 'Jacomo', 'jil sander',
#        'MINI COLLECTION', 'CHANEL', 'ADOLFO DOMINGUEZ', 'Fendi', 'ROCHAS',
#        'Michael Kors', 'Parfums De Marly', 'Miu Miu', 'TESORI D´ORIENTE',
#        'Lolita Lempicka', 'Nikos', 'ROGER & GALLET', 'CREED',
#        'Mercedes-Benz', 'Shirley May', 'Parfums Gres', 'Marc Jacobs',
#        'Remy Marquis', 'LANVIN PARIS', 'CARON', 'MING NA', 'Mont Blanc',
#        'adidas', "PENHALIGON'S", 'Laura Biagiotti', 'Armaf', 'HOUBIGANT',
#        'NICOLAI', 'Aramis', 'marbert man', 'DIESEL', 'Emper', 'Shiseido',
#        'TOM FORD', 'MOSCHINO', 'NINA RICCI', 'LA PERLA', 'Justcavalli',
#        'Arabian Oud', 'ISSEY MIYAKE', 'Creation Lamis', 'YVES',
#        'Misk Perfumes', 'Pierra Katra', 'ARMAND BASI', 'SWISS ARABIAN',
#        'al raheeb', 'Bill Blass', 'Al Rasasi', 'Dorall', 'MB',
#        'ST Dupont', 'STELLA MCCARTNEY', 'Mandarina Duck', 'TRI', 'Gres',
#        'Niya', 'Genie Collection', 'Elizabeth Taylor', 'Roberto', 'JOVAN'],
#       dtype=object)

# %% [markdown]
# # Add columns for the price deduction, deduction range, and price per ml.

# %%
data['price_deduction']=data['old_price']-data['new_price']
data['%_of_deduction']=((data['price_deduction']/data['old_price']).round(4))*100
data['price_per_ml']=(data['new_price']/data['ml']).round(2)

# %%
data
# Out:
#                 brand                      name  old_price  new_price   ml  \
# 0        PACO RABANNE           1 Million Lucky      395.0     244.55  100
# 1     Roberto Cavalli         Paradiso Assoluto      415.0     107.95   50
# 2          S.T.Dupont               Royal Amber      265.0     186.90  100
# 3               GUESS            Seductive Blue      290.0     103.20  100
# 4     Roberto Cavalli                      Uomo      260.0      94.95   50
# ...               ...                       ...        ...        ...  ...
# 998             GUESS                      Dare      170.0      75.00  100
# 999          BURBERRY  For Women EDP Natural Sp      378.0     153.75  100
# 1000            JOVAN           Musk Cologne Sp       55.0      19.00   59
# 1001    SWISS ARABIAN             Layali CPO At      126.0      77.00   15
# 1002          LACOSTE        L.12.12 Blanc-Pure      347.0      94.20  100
#
#      concentration department   scents  \
# 0              EDT        Men    Woody
# 1              EDP      Women   Floral
# 2              EDP     Unisex  Arabian
# 3              EDT        Men    Spicy
# 4              EDP      Women  Arabian
# ...            ...        ...      ...
# 998            EDT      Women   Citrus
# 999            EDT      Women   Fruity
# 1000           EDT      Women    Woody
# 1001           EDT     Unisex  Arabian
# 1002           EDT        Men    Woody
#
#                                         base_note  \
# 0                  Oakmoss, Patchouli and Vetiver
# 1               Vanilla, Sandalwood And Patchouli
# 2                       Lemon, Mint and Wood Moss
# 3     Cashmere Wood, Moss And Rippled Sand Accord
# 4                    Vanille, Benzoin, Tonka Bean
# ...                                           ...
# 998                   Coconut Accords, Wood, Musk
# 999                              Musk And Vanilla
# 1000                            Musk, Amber, Wood
# 1001                           Agarwood and Amber
# 1002      Virginia Cedar, Leather, Suede, Vetiver
#
#                                            middle_note  item_rating  \
# 0     Hazelnut, Jasmine, Cashmir Wood, Cedar and Honey          5.0
# 1                            Wild Jasmine and Red Lily          4.8
# 2                                 Sandalwood and Cedar          5.0
# 3             Blue Coral Aquaspace Accord And Geranium          3.0
# 4                                African Orange Flower          4.8
# ...                                                ...          ...
# 998                         Wild Rose, Elegant Jasmine          4.9
# 999                 Woody-Floral, Sandalwood And Cedar          4.8
# 1000                                       Ylang-ylang          4.7
# 1001                     Ylang-Ylang, Rose and Jasmine          4.0
# 1002                             Ylang-Ylang, Tuberose          4.6
#
#                                                  seller  seller_rating  \
# 0                                                  noon            4.2
# 1                                                  noon            4.2
# 2                                                  noon            4.2
# 3                                                  noon            4.2
# 4                                                  noon            4.2
# ...                                                 ...            ...
# 998                                                noon            4.2
# 999                                                noon            4.2
# 1000                                               Cute            3.7
# 1001  Swiss Arabian PerfumesPRICE UPDATE WITH 15% VA...            3.9
# 1002                                               noon            4.2
#
#      num_seller_ratings  price_deduction  %_of_deduction  price_per_ml
# 0                 98.1K           150.45           38.09          2.45
# 1                 98.1K           307.05           73.99          2.16
# 2                 98.1K            78.10           29.47          1.87
# 3                 98.1K           186.80           64.41          1.03
# 4                 98.1K           165.05           63.48          1.90
# ...                 ...              ...             ...           ...
# 998               98.1K            95.00           55.88          0.75
# 999               98.1K           224.25           59.33          1.54
# 1000               1.9K            36.00           65.45          0.32
# 1001                  5            49.00           38.89          5.13
# 1002              98.1K           252.80           72.85          0.94
#
# [1003 rows x 17 columns]

# %% [markdown]
# # Analyze

# %%
# Determining the scope of the discount in relation to different sexual categories

# %%
men=data[data['department']=='Men']
women=data[data['department']=='Women']
unisex=data[data['department']=='Unisex']

# %%
avg_price_men=men['new_price'].mean() 
avg_discount_men=men['price_deduction'].mean() 
avg_price_men=men['new_price'].mean()
avg_discount_men=men['price_deduction'].mean()

# %%
avg_price_women=women['new_price'].mean() 
avg_discount_women=women['price_deduction'].mean()
avg_price_women=women['new_price'].mean()
avg_discount_women=women['price_deduction'].mean()

# %%
avg_old_price = data.groupby('department')['old_price'].mean().reset_index()
avg_new_price = data.groupby('department')['new_price'].mean().reset_index()
sns.barplot(x="department",  y="old_price", data=avg_old_price, color='pink', label='Average Price Reduction') #متوسط تخفيض السعر
sns.barplot(x="department", y="new_price", data=avg_new_price, color='lightblue', label='Average New Price') #متوسط السعر الجديد
sns.set_context("talk")
plt.title('Price Reduction')
plt.xlabel('Category')
plt.ylabel('Price')
plt.legend(bbox_to_anchor=(1, 1), loc='upper left')
plt.show()

# %%
#From this histogram, it shows unisex perfume products are not as expensive as male and female ones.

# %%
plt.hist(men['price_per_ml'], alpha=0.4, label='Men',color='lightblue', density=False)
plt.hist(women['price_per_ml'], alpha=0.4, label='Women',color='pink', density=False)
plt.hist(unisex['price_per_ml'], alpha=0.4, label='Unisex',color='#194553', density=False)
plt.yscale('log')
plt.xticks(ticks=[0,2,4,6,8,10,12], labels=None)
plt.title('Comparison of the Price per ml')
plt.xlabel('Price per ml')
plt.ylabel('Number of Items')
plt.legend()
plt.show()

# %%
#From scatter charts, it demonstrates more women perfumes still get 4-5 star reviews, althoght the price is slightly higher.

# %%
rate_jitter=data['item_rating']+np.random.normal(1,1.1,size=len(data))
sns.relplot(x=data['price_per_ml'], y=rate_jitter, kind='scatter', hue=data['department'], alpha=0.6, size=data['price_per_ml'], col=data['department'], col_wrap=2 ,color='pink')
plt.xticks(ticks=[0,2,4,6,8,10,12], labels=None)
plt.show()

# %%
#From the below chart, it tells there is a trend that a product with a higher price would perhaps result a better review. Here only shows a chart for men's perfume#

# %%
men_base_str=men['base_note'].str.cat(sep=' ')
men_middle_str=men['middle_note'].str.cat(sep=' ')
men_str=men_base_str+men_middle_str
punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
men_str_nopunc = ""
for word in men_str:
    if word not in punctuations:
        men_str_nopunc = men_str_nopunc + word
men_str_clean_and=men_str_nopunc.replace(' and ', '')
men_str_clean_And=men_str_clean_and.replace(' And ', '')
men_str_cleaned=men_str_clean_And.replace(' Notes ', '')

# %%
def word_count(str):
    counts = {}
    words = str.split()
    for word in words:
        if word in counts:
            counts[word] += 1
        else:
            counts[word] = 1
    return counts

men_note_lib=word_count(men_str_cleaned)
sort_men = sorted(men_note_lib.items(), key=lambda x: x[1], reverse=True)

#conver a dictionary to a dataframe
men_note_df=pd.DataFrame(men_note_lib.items(), columns=['base_note', 'frequency'])
men_note_df.sort_values('frequency', ascending=False).head(10)
# Out:
#       base_note  frequency
# 17        Cedar        120
# 11        Amber        120
# 14    Patchouli        116
# 13   Sandalwood        114
# 12         Musk        102
# 32      Vetiver         87
# 29        Tonka         80
# 301     Jasmine         70
# 30         Bean         66
# 434    Geranium         64

# %%
men_note_top10=men_note_df.sort_values('frequency', ascending=False).head(10)
sns.catplot(x='frequency', y='base_note', data=men_note_top10, kind='bar', height=4, aspect=16/9)
plt.title('Top 10 Scent Notes for M en')
plt.xlabel('Frequency')
plt.ylabel('Scent Notes')
plt.show()

# %%
#here demonstrates the top 10 scent notes,men

# %%
women_base_str=women['base_note'].str.cat(sep=' ')
women_middle_str=women['middle_note'].str.cat(sep=' ')
women_str=women_base_str+women_middle_str
women_str_nopunc = ""
for word in women_str:
    if word not in punctuations:
        women_str_nopunc = women_str_nopunc + word
women_str_clean_and=women_str_nopunc.replace(' and ', '')
women_str_clean_And=women_str_clean_and.replace(' And ', '')
women_str_cleaned=women_str_clean_And.replace(' Notes ', '')


#display the top 10 scent notes for women
women_note_lib=word_count(women_str_cleaned)
sort_women = sorted(women_note_lib.items(), key=lambda x: x[1], reverse=True)
women_note_df=pd.DataFrame(women_note_lib.items(), columns=['note', 'frequency'])
women_note_df.sort_values('frequency', ascending=False).head(10)
# Out:
#            note  frequency
# 25      Jasmine        198
# 9          Musk        190
# 66         Rose        160
# 0       Vanilla        137
# 8    Sandalwood        128
# 16        Amber        124
# 12    Patchouli         91
# 124     Blossom         71
# 383      Orange         64
# 10        Cedar         62

# %%
women_note_top10=women_note_df.sort_values('frequency', ascending=False).head(10)
sns.catplot(x='frequency', y='note', data=women_note_top10, kind='bar', height=4, aspect=16/9)
plt.title('Top 10 Scent Notes for Women')
plt.xlabel('Frequency')
plt.ylabel('Scent Notes')
plt.show()

# %%
unisex_base_str=unisex['base_note'].str.cat(sep=' ')
unisex_middle_str=unisex['middle_note'].str.cat(sep=' ')
unisex_str=unisex_base_str+unisex_middle_str
unisex_str_nopunc = ""
for word in unisex_str:
    if word not in punctuations:
         unisex_str_nopunc = unisex_str_nopunc + word
unisex_str_clean_and=unisex_str_nopunc.replace(' and ', '')
unisex_str_clean_And=unisex_str_clean_and.replace(' And ', '')
unisex_str_cleaned=unisex_str_clean_And.replace(' Notes ', '')

#display the top 10 scent notes for unisex
unisex_note_lib=word_count(unisex_str_cleaned)
sort_unisex = sorted(unisex_note_lib.items(), key=lambda x: x[1], reverse=True)
unisex_note_df=pd.DataFrame(unisex_note_lib.items(), columns=['note', 'frequency'])
unisex_note_df.sort_values('frequency', ascending=False).head(10)
# Out:
#            note  frequency
# 5         Amber         25
# 8          Musk         22
# 68         Rose         14
# 15   Sandalwood         14
# 9       Vanilla         14
# 104     Jasmine         13
# 21    Patchouli         12
# 22        Cedar          9
# 4          Wood          9
# 49        Woody          6

# %%
unisex_note_top10=unisex_note_df.sort_values('frequency', ascending=False).head(10)
sns.catplot(x='frequency', y='note', data=unisex_note_top10, kind='bar', height=4, aspect=16/9)
plt.title('Top 10 Scent Notes for Unisex')
plt.xlabel('Frequency')
plt.ylabel('Scent Notes')
plt.show()

# %%
du=data.groupby('brand')[['item_rating']].max().sort_values(by='item_rating',ascending=False).sample(25)
du
# Out:
#                     item_rating
# brand
# Gres                        4.6
# ANGEL SCHLESSER             4.6
# TED LAPIDUS                 5.0
# CERRUTI 1881                4.3
# Yves Saint Laurent          5.0
# Parfums Gres                4.8
# armani                      5.0
# CARON                       4.3
# MONTBLANC                   5.0
# Ferrari                     5.0
# Shirley May                 4.5
# Alina Corel                 5.0
# ROCHAS                      3.0
# TOMMY HILFIGER              5.0
# Elizabeth Arden             5.0
# EMPORIO ARMANI              4.9
# cacharel                    4.5
# Michael Kors                5.0
# GUESS                       5.0
# AMOUAGE                     5.0
# YVES                        5.0
# LANVIN PARIS                5.0
# MB                          4.5
# Aramis                      5.0
# Laura Biagiotti             4.5

# %%
plt.figure(figsize=[14,8])
plt.bar(du.index,du.item_rating)
plt.xticks(rotation=90);

# %%
regression=linregress(men['price_per_ml'], men['item_rating'])
print(regression)
# Out:
# LinregressResult(slope=0.05301151715837076, intercept=4.384705988951069, rvalue=0.107108648652559, pvalue=0.025829951995361783, stderr=0.023702900228221968, intercept_stderr=0.045291368181624596)

# %%
fx=np.array([men['price_per_ml'].min(), men['price_per_ml'].max()])
fy=regression.intercept+regression.slope*fx
rate_jitter_men=men['item_rating']+np.random.normal(0,0.1,size=len(men))
sns.relplot(x=men['price_per_ml'], y=rate_jitter_men, kind='scatter', alpha=0.8, size=men['price_per_ml'])
plt.xticks(ticks=[0,2,4,6,8,10,12], labels=None)
plt.plot(fx, fy, '--', color='red')
plt.xscale("log")
plt.title('Regression between the Price and the Stars', y=1.04)
plt.xlabel('Price per ml')
plt.ylabel('Stars')
plt.show()

# %%
regression=linregress(women['price_per_ml'], women['item_rating'])
print(regression)
# Out:
# LinregressResult(slope=-0.012048170007047521, intercept=4.620821290936539, rvalue=-0.03291359466564266, pvalue=0.46140335213882044, stderr=0.016345249098577735, intercept_stderr=0.03992982374672849)

# %%
fx=np.array([men['price_per_ml'].min(), men['price_per_ml'].max()])
fy=regression.intercept+regression.slope*fx
rate_jitter_men=men['item_rating']+np.random.normal(0,0.1,size=len(men))
sns.relplot(x=men['price_per_ml'], y=rate_jitter_men, kind='scatter', alpha=0.8,color='pink', size=men['price_per_ml'])
plt.xticks(ticks=[0,2,4,6,8,10,12], labels=None)
plt.plot(fx, fy, '--', color='red')
plt.xscale("log")
plt.title('Regression between the Price and the Stars', y=1.04)
plt.xlabel('Price per ml')
plt.ylabel('Stars')
plt.show()
